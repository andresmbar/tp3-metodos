# %% [markdown]
# # Accuracy

# %% [markdown]
# ## KNN + PCA

# %%
import csv

import pandas as pd
with open('../resultados/knn_pca_acuracy.csv', newline='') as csvfile:
    spamreader = csv.reader(csvfile, delimiter=(','), quotechar='|')

    for row in spamreader:
        raw_data = row
    
    # Me quedo la data sucia con "[ y ]" en los extremos, los quiero sacar.
    data = [] 
    cols = ['alpha','k','accuracy']
    result = 0
    for i in range(0,len(raw_data),3):
        data_row = [ ]
        alpha = raw_data[i][2:]
        k = raw_data[i+1][1:]
        accuracy = raw_data[i+2][1:-2]
        data_row.append(int(alpha))
        data_row.append(int(k))
        data_row.append(float(accuracy))
        data.append(data_row)
    df=pd.DataFrame(data,columns=['alpha','k','accuracy'])
    df = df.sort_values('accuracy',ascending = False)
    print(df)
# Out:
# 1
# 1001
# 2001
# 3001
# 4001
# 5001
# 6001
# 7001
# 8001
# 9001
# 10001
# 11001
# 12001
# 13001
# 14001
# 15001
# 16001
# 17001
# 18001
# 19001
# 20001
# 21001
# 22001
# 23001
# 24001
# 25001
# 26001
# 27001
# 28001
# 29001
# 30001
# 31001
# 32001
# 33001
# 1
# 1001
# 2001
# 3001
# 4001
# 5001
# 6001
# 7001
# 8001
# 9001
# 10001
# 11001
# 12001
# 13001
# 14001
# 15001
# 16001
# 17001
# 18001
# 19001
# 20001
# 21001
# 22001
# 23001
# 24001
# 25001
# 26001
# 27001
# 28001
# 29001
# 30001
# 31001
# 32001
# 33001
# 1
# 1001
# 2001
# 3001
# 4001
# 5001
# 6001
# 7001
# 8001
# 9001
# 10001
# 11001
# 12001
# 13001
# 14001
# 15001
# 16001
# 17001
# 18001
# 19001
# 20001
# 21001
# 22001
# 23001
# 24001
# 25001
# 26001
# 27001
# 28001
# 29001
# 30001
# 31001
# 32001
# 33001
# 1
# 1001
# 2001
# 3001
# 4001
# 5001
# 6001
# 7001
# 8001
# 9001
# 10001
# 11001
# 12001
# 13001
# 14001
# 15001
# 16001
# 17001
# 18001
# 19001
# 20001
# 21001
# 22001
# 23001
# 24001
# 25001
# 26001
# 27001
# 28001
# 29001
# 30001
# 31001
# 32001
# 33001
# 1
# 1001
# 2001
# 3001
# 4001
# 5001
# 6001
# 7001
# 8001
# 9001
# 10001
# 11001
# 12001
# 13001
# 14001
# 15001
# 16001
# 17001
# 18001
# 19001
# 20001
# 21001
# 22001
# 23001
# 24001
# 25001
# 26001
# 27001
# 28001
# 29001
# 30001
# 31001
# 32001
# 33001
# 1
# 1001
# 2001
# 3001
# 4001
# 5001
# 6001
# 7001
# 8001
# 9001
# 10001
# 11001
# 12001
# 13001
# 14001
# 15001
# 16001
# 17001
# 18001
# 19001
# 20001
# 21001
# 22001
# 23001
# 24001
# 25001
# 26001
# 27001
# 28001
# 29001
# 30001
# 31001
# 32001
# 33001
# 1
# 1001
# 2001
# 3001
# 4001
# 5001
# 6001
# 7001
# 8001
# 9001
# 10001
# 11001
# 12001
# 13001
# 14001
# 15001
# 16001
# 17001
# 18001
# 19001
# 20001
# 21001
# 22001
# 23001
# 24001
# 25001
# 26001
# 27001
# 28001
# 29001
# 30001
# 31001
# 32001
# 33001
#      alpha      k  accuracy
# 204     25      1  0.965595
# 170     21      1  0.965000
# 136     17      1  0.957857
# 102     13      1  0.941667
# 68       9      1  0.889286
# 171     21   1001  0.880357
# 205     25   1001  0.877738
# 137     17   1001  0.872262
# 103     13   1001  0.854167
# 172     21   2001  0.835714
# 206     25   2001  0.833214
# 138     17   2001  0.829524
# 69       9   1001  0.825952
# 104     13   2001  0.812500
# 173     21   3001  0.799643
# 139     17   3001  0.798214
# 207     25   3001  0.794524
# 70       9   2001  0.789405
# 105     13   3001  0.782262
# 140     17   4001  0.772976
# 174     21   4001  0.772619
# 208     25   4001  0.768095
# 71       9   3001  0.763095
# 106     13   4001  0.758571
# 175     21   5001  0.750833
# 141     17   5001  0.749048
# 209     25   5001  0.743095
# 72       9   4001  0.739762
# 107     13   5001  0.737500
# 176     21   6001  0.728333
# ..     ...    ...       ...
# 199     21  29001  0.173571
# 98       9  30001  0.171667
# 30       1  30001  0.166548
# 233     25  29001  0.163929
# 132     13  30001  0.162024
# 64       5  30001  0.158571
# 166     17  30001  0.151905
# 200     21  30001  0.145357
# 99       9  31001  0.144643
# 234     25  30001  0.141667
# 31       1  31001  0.139286
# 65       5  31001  0.139048
# 133     13  31001  0.136548
# 167     17  31001  0.131905
# 201     21  31001  0.128690
# 100      9  32001  0.125714
# 32       1  32001  0.125714
# 235     25  31001  0.125476
# 66       5  32001  0.125238
# 134     13  32001  0.124167
# 168     17  32001  0.120357
# 202     21  32001  0.117619
# 33       1  33001  0.117262
# 236     25  32001  0.116786
# 101      9  33001  0.116071
# 67       5  33001  0.115000
# 135     13  33001  0.114762
# 169     17  33001  0.114048
# 203     21  33001  0.113690
# 237     25  33001  0.113571
#
# [238 rows x 3 columns]

# %%
import seaborn as sns
import pandas as pd

pivot = df.pivot(index='alpha', columns='k', values='accuracy')
ax = sns.heatmap(pivot,annot=False)
plt.savefig('../resultados/knn_pca_acuracy', dpi =500,bbox_inches = "tight")
plt.show()

# %% [markdown]
# # KNN solo

# %%
import csv
import re
import pandas as pd
import matplotlib.pyplot as plt
with open('../resultados/knn_solo_acuracy.csv', newline='') as csvfile:
    spamreader = csv.reader(csvfile, delimiter=(','), quotechar='|')
    data = []
    for row in spamreader:
        data =[float(i[2:-2]) for i in row]
    k_index = []
    for i in range(1,33600,500):
        k_index.append(i)

    plt.scatter(k_index, data)
    plt.title('Relacion entre la eleecion de vecinos y su accuracy') #title
    plt.xlabel('K vecinos mas cercanos') #x label
    plt.ylabel('Accuracy') #y label
    plt.savefig('../resultados/knn_solo_acuracy')
    plt.show()
