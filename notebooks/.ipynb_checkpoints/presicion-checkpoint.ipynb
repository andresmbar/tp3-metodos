# %% [markdown]
# # Precision

# %% [markdown]
# # Knn solo

# %%
import csv

import pandas as pd
with open('../resultados/knn_solo_precision.csv', newline='') as csvfile:
    spamreader = csv.reader(csvfile, delimiter=(','), quotechar='|')
    numbers = next(spamreader)
    data = []
    for row in spamreader:
        data_row = [float(i) for i in row]
        data.append(data_row)
df = pd.DataFrame(data, columns =numbers)
print(df)
# Out:
#            0         1         2         3         4         5         6  \
# 0   0.983193  0.960084  0.975962  0.951049  0.963840  0.953581  0.976718
# 1   0.939181  0.668609  0.981366  0.874854  0.954738  0.930197  0.928097
# 2   0.933649  0.577722  0.977273  0.845519  0.929851  0.930851  0.900438
# 3   0.933575  0.513695  0.978599  0.815944  0.912577  0.934694  0.885650
# 4   0.930488  0.467684  0.977459  0.789164  0.908946  0.938534  0.870307
# 5   0.931119  0.438873  0.976242  0.770060  0.884615  0.935401  0.866279
# 6   0.935849  0.413219  0.975391  0.749698  0.877686  0.928161  0.857647
# 7   0.936468  0.390731  0.974178  0.730627  0.864548  0.932258  0.848921
# 8   0.935567  0.370714  0.975062  0.713217  0.849662  0.937037  0.838983
# 9   0.936281  0.355650  0.976923  0.701135  0.840480  0.932489  0.834363
# 10  0.939073  0.340118  0.973615  0.688630  0.831325  0.914286  0.831858
# 11  0.938503  0.328214  0.970109  0.677588  0.828371  0.913706  0.825130
# ...

# %%
import seaborn as sns
sns.heatmap(df, annot=False)

# %% [markdown]
# ## KNN + PCA

# %%
import csv

import pandas as pd
with open('../resultados/knn_pca_precision.csv', newline='') as csvfile:
    spamreader = csv.reader(csvfile, delimiter=(','), quotechar='|')
    numbers = next(spamreader)
    data = []
    for row in spamreader:
        data_row = [float(i) for i in row]
        data.append(data_row)
df = pd.DataFrame(data, columns =numbers)
print(df)
# Out:
#      alpha        k         0         1         2         3         4  \
# 0      1.0      1.0  0.563412  0.780538  0.111922  0.132961  0.139975
# 1      1.0   1001.0  0.550430  0.772563  0.164384  0.173653  0.062500
# 2      1.0   2001.0  0.560096  0.764342  0.240000  0.175157  0.000000
# 3      1.0   3001.0  0.560995  0.741365  0.000000  0.175221  0.000000
# 4      1.0   4001.0  0.562855  0.727422  0.000000  0.176928  0.000000
# 5      1.0   5001.0  0.563209  0.709626  0.000000  0.174460  0.000000
# 6      1.0   6001.0  0.559648  0.692130  0.000000  0.171221  0.000000
# 7      1.0   7001.0  0.555203  0.675676  0.000000  0.173741  0.000000
# 8      1.0   8001.0  0.559200  0.659124  0.000000  0.169287  0.000000
# 9      1.0   9001.0  0.561446  0.643213  0.000000  0.169396  0.000000
# 10     1.0  10001.0  0.563107  0.625172  0.000000  0.168464  0.000000
# 11     1.0  11001.0  0.564687  0.611670  0.000000  0.168722  0.000000
# ...
